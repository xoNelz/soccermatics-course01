# %% [markdown]
# # Getting Started with StatsBomb Data
#
# This notebook is the first lesson in the Soccermatics course by David Sumpter.
#
# **Goals:**
# - Load StatsBomb open data using the `statsbombpy` library
# - Explore the competitions and matches available
# - Take a first look at event-level data
#
# **Libraries used:** `statsbombpy`, `pandas`

# %%
from statsbombpy import sb
import pandas as pd

# %%
competitions = sb.competitions()
competitions.head()
# Out:
# c:\Users\osisi\OneDrive\Desktop\dataComics\soccermatics-course01\venv\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#    competition_id  season_id country_name        competition_name  \
# 0               9        281      Germany           1. Bundesliga
# 1               9         27      Germany           1. Bundesliga
# 2            1267        107       Africa  African Cup of Nations
# 3              16          4       Europe        Champions League
# 4              16          1       Europe        Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                       True
# 3               male              False                      False
# ...

# %%
competitions.shape
# Out:
# (75, 12)

# %%
competitions.columns.tolist()
# Out:
# ['competition_id',
#  'season_id',
#  'country_name',
#  'competition_name',
#  'competition_gender',
#  'competition_youth',
#  'competition_international',
#  'season_name',
#  'match_updated',
#  'match_updated_360',
#  'match_available_360',
#  'match_available']

# %%
competitions[competitions['competition_gender'] == 'female']
# Out:
#     competition_id  season_id              country_name  \
# 25              37         90                   England
# 26              37         42                   England
# 27              37          4                   England
# 63              49          3  United States of America
# 71              53        315                    Europe
# 72              53        106                    Europe
# 73              72        107             International
# 74              72         30             International
#
#            competition_name competition_gender  competition_youth  \
# 25  FA Women's Super League             female              False
# 26  FA Women's Super League             female              False
# 27  FA Women's Super League             female              False
# 63                     NWSL             female              False
# 71        UEFA Women's Euro             female              False
# ...
